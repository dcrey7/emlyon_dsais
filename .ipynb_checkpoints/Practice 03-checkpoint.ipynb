# %% [markdown]
# <table style="float:left">
#     <tr>
#         <td>
#             <img src="images/emlyon.png" style="height:60px; float:left; padding-right:10px; margin-top:5px" />
#         </td>
#         <td style="padding-bottom:10px;">
#             <h1 style="border-bottom: 1px solid #eeeeee;"> AI Booster Week 01 - Python for Data Science </h1>
#             <span style="display:inline-block; margin-top:-15px;">
#             <a href="https://masters.em-lyon.com/fr/msc-in-data-science-artificial-intelligence-strategy">[Emlyon]</a> MSc in Data Science & Artificial Intelligence Strategy (DSAIS)
#             <br/>
#             Sep 2024, Paris | © Laureline PINAULT | Vincent SCHOOTS
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # Practice - 03: Studying an Olympic dataset with Python and Pandas Library
# The bonus questions are to be skipped. If you have time left at the end of the session or at home you can try them.

# %% [markdown]
# ---
# ### Objectives:
#
# *Discover pandas by practicing over a real dataset.*
#
# ---

# %% [markdown]
# The dataset comes from kaggle, a website containing a lot of open datasets. Its description and some information (how the data has been collected for instance) are available at the following webpage:
# https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results?resource=download

# %% [markdown]
# ## Part 1: Loading and exploring the data

# %% [markdown]
# __Question 1.__
# Open the csv file in the path location as a pandas dataframe and display it.

# %%
import numpy as np

# %%
import pandas as pd

path = "data/athlete_events.csv"
df=pd.read_csv(path)
df.head()
#Your code:
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# __Question 2.__
# Use Pandas functions to get some information about the dataset and write a description sentence containing at least nb of rows, nb of columns and nb of values.
#
# Then display the name of the different columns with at least 3 differents methods. Which one(s) also display columns' datatypes?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# __Question 3.__
# Display the 5 first and 10 last records of the dataframe.

# %%
df.head(5)
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df.tail(10)
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571            Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                  Team  NOC        Games  Year  Season            City  \
# 271106      Argentina  ARG  2004 Summer  2004  Summer          Athina
# 271107  United States  USA  1972 Summer  1972  Summer          Munich
# 271108         Russia  RUS  2000 Summer  2000  Summer          Sydney
# 271109         Russia  RUS  2004 Summer  2004  Summer          Athina
# 271110        Belarus  BLR  2016 Summer  2016  Summer  Rio de Janeiro
# 271111       Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112         Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113         Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114         Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115         Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#               Sport                                     Event Medal
# 271106       Hockey                       Hockey Men's Hockey   NaN
# 271107     Football                   Football Men's Football   NaN
# 271108       Rowing    Rowing Men's Lightweight Coxless Fours   NaN
# 271109       Rowing    Rowing Men's Lightweight Coxless Fours   NaN
# 271110   Basketball             Basketball Women's Basketball   NaN
# 271111         Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113  Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114    Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115    Bobsleigh                      Bobsleigh Men's Four   NaN

# %% [markdown]
# __Question 4.__
# Get statistical indicators of the numeric columns.

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ## Part 2: Modifying the data

# %% [markdown]
# __Question 1.__
# Add the unit of measurement to the Height and Weight column name (inside parentheses). Make sure that your dataframe is updated.

# %%
df.rename(columns={"Height":"Height(cm)","Weight":"Weight(kg)"},inplace=True)
df.head()
# Out:
#    ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0   1                 A Dijiang   M  24.0       180.0        80.0
# 1   2                  A Lamusi   M  23.0       170.0        60.0
# 2   3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3   4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4   5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
#
#              Team  NOC        Games  Year  Season       City          Sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# __Question 2.__
# The column Games does not interest us since the information is already contained in the columns Year and Season: remove it. Make sure that your dataframe is updated.

# %%
df.drop("Games",axis=1,inplace=True)
df.head()
# Out:
#    ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0   1                 A Dijiang   M  24.0       180.0        80.0
# 1   2                  A Lamusi   M  23.0       170.0        60.0
# 2   3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3   4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4   5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
#
#              Team  NOC  Year  Season       City          Sport  \
# 0           China  CHN  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012  Summer     London           Judo
# 2         Denmark  DEN  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# __Question 3.__
# We want to add a column that directly tells us wether the athlete has won a medal or not. For this we will rename the Medal column 'Medal_type' and add a new column named 'Medal' with this information.

# %%
#First, rename the original Medal column. 
#Make sure that your dataframe is updated.
df.rename(columns={"Medal":"Medal_type"},inplace=True)
df.head()
# Out:
#    ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0   1                 A Dijiang   M  24.0       180.0        80.0
# 1   2                  A Lamusi   M  23.0       170.0        60.0
# 2   3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3   4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4   5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
#
#              Team  NOC  Year  Season       City          Sport  \
# 0           China  CHN  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012  Summer     London           Judo
# 2         Denmark  DEN  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal_type
# 0       Basketball Men's Basketball        NaN
# 1      Judo Men's Extra-Lightweight        NaN
# 2           Football Men's Football        NaN
# 3       Tug-Of-War Men's Tug-Of-War       Gold
# 4  Speed Skating Women's 500 metres        NaN

# %%
winners=list(df["Medal_type"].unique())
winners
# Out:
# [nan, 'Gold', 'Bronze', 'Silver']

# %%
#Then we will add the new Medal column.
df["Medal"]=np.nan
#Find the different values that exist in the Medal_type column (tip: use the function .unique())
#Then write a function that returns true when the athlete won a medal (tip: use logic operators (Session 1).
winners=list(df["Medal_type"].unique())

    
df['thanks']=df['Medal_type'].apply(lambda x: True if x in winners[1:] else False)
df.head()
#Create the new column thanks to the function.
#Don't forget to verify it worked correctly, by retrieving the new column again! 
#(tip: use the function .drop_duplicate())
# Out:
#    ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0   1                 A Dijiang   M  24.0       180.0        80.0
# 1   2                  A Lamusi   M  23.0       170.0        60.0
# 2   3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3   4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4   5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
#
#              Team  NOC  Year  Season       City          Sport  \
# 0           China  CHN  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012  Summer     London           Judo
# 2         Denmark  DEN  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal_type  Medal  thanks
# 0       Basketball Men's Basketball        NaN    NaN   False
# 1      Judo Men's Extra-Lightweight        NaN    NaN   False
# 2           Football Men's Football        NaN    NaN   False
# 3       Tug-Of-War Men's Tug-Of-War       Gold    NaN    True
# 4  Speed Skating Women's 500 metres        NaN    NaN   False

# %% [markdown]
# __Question 4. (bonus)__
# Remove the sport part from the event column.

# %%
# for i in df['Sport']:
#     print(i)

# %%
def replacesports(element1, element2):
    return element2.replace(element1,"",1)


# Applying it to two columns
df["Event"] = df.apply(lambda x: replacesports(x["Sport"], x["Event"]), axis=1)

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0   1                 A Dijiang   M  24.0       180.0        80.0
# 1   2                  A Lamusi   M  23.0       170.0        60.0
# 2   3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3   4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4   5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
#
#              Team  NOC  Year  Season       City          Sport  \
# 0           China  CHN  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012  Summer     London           Judo
# 2         Denmark  DEN  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988  Winter    Calgary  Speed Skating
#
#                       Event Medal_type  Medal  thanks
# 0          Men's Basketball        NaN    NaN   False
# 1   Men's Extra-Lightweight        NaN    NaN   False
# 2            Men's Football        NaN    NaN   False
# 3          Men's Tug-Of-War       Gold    NaN    True
# 4        Women's 500 metres        NaN    NaN   False

# %%
# new_values = []
# for i, row in df.iterrows():
#     new_values.append( row["Event"].replace( row["Sport"], "" , 1) )
    
# df["Event"] = new_values
# df.head()

# %% [markdown]
# __Question 5.__
# The file "noc_regions.csv" contains the correspondance between the NOC code and the countries. Add this information to the dataframe. Tip: have a good look at the .merge() method discussed in class. Name the new column 'Countries' and place it just after the NOC column.

# %%
# dfh

# %%
noc_df=pd.read_csv(r'data/noc_regions.csv')
noc_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# __Question 6.__
# Save your modified dataset in a csv file named 'athlete_events_modified' in the data folder.

# %%
df1=pd.merge(df,noc_df[['NOC',"region"]],on="NOC",how="left")
df1.rename(columns={"region":"Countries"},inplace=True)
df1.head()
# Out:
#    ID                      Name Sex   Age  Height(cm)  Weight(kg)  \
# 0   1                 A Dijiang   M  24.0       180.0        80.0
# 1   2                  A Lamusi   M  23.0       170.0        60.0
# 2   3       Gunnar Nielsen Aaby   M  24.0         NaN         NaN
# 3   4      Edgar Lindenau Aabye   M  34.0         NaN         NaN
# 4   5  Christine Jacoba Aaftink   F  21.0       185.0        82.0
#
#              Team  NOC  Year  Season       City          Sport  \
# 0           China  CHN  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012  Summer     London           Judo
# 2         Denmark  DEN  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988  Winter    Calgary  Speed Skating
#
#                       Event Medal_type  Medal  thanks    Countries
# 0          Men's Basketball        NaN    NaN   False        China
# 1   Men's Extra-Lightweight        NaN    NaN   False        China
# 2            Men's Football        NaN    NaN   False      Denmark
# 3          Men's Tug-Of-War       Gold    NaN    True      Denmark
# 4        Women's 500 metres        NaN    NaN   False  Netherlands

# %%
df1.to_csv(r'data/athlete_events_modified.csv')

# %% [markdown]
# ## Part 3: Computing with the data

# %% [markdown]
# __Question 1.__
# Display the average age depending on wether a medal has been won or not. Is there a meaningful difference?

# %%
df1.groupby("thanks")["Age"].mean()
# Out:
# thanks
# False    25.492289
# True     25.925175
# Name: Age, dtype: float64

# %% [markdown]
# __Question 2.__
# Find out the yougest athlete(s) to ever win a medal. (Expected result: the row(s) containing all their data).

# %%
df[df["Age"]==df[df["thanks"]==True]["Age"].min()]
# Out:
#            ID                Name Sex   Age  Height(cm)  Weight(kg)  \
# 142882  71691  Dimitrios Loundras   M  10.0         NaN         NaN
#
#                                  Team  NOC  Year  Season    City       Sport  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896  Summer  Athina  Gymnastics
#
#                               Event Medal_type  Medal  thanks
# 142882   Men's Parallel Bars, Teams     Bronze    NaN    True

# %% [markdown]
# __Question 3.__
# Disply a table with the average height and weight for each sport. Include only the summer seasons of olympic games and sort your result by average height.

# %%
df[df['Season']=="Summer"].groupby("Sport")[["Height(cm)","Weight(kg)"]].mean()
# Out:
#                        Height(cm)  Weight(kg)
# Sport
# Aeronautics                   NaN         NaN
# Alpinism                      NaN         NaN
# Archery                173.203085   70.011135
# Art Competitions       174.644068   75.290909
# Athletics              176.256268   69.249287
# Badminton              174.178803   68.171439
# Baseball               182.599291   85.707792
# Basketball             190.869879   85.777053
# Basque Pelota                 NaN         NaN
# Beach Volleyball       186.144954   79.089219
# Boxing                 172.825688   65.249890
# Canoeing               178.539568   76.492615
# Cricket                       NaN         NaN
# Croquet                       NaN         NaN
# Cycling                176.108826   70.067944
# Diving                 166.634264   60.572741
# Equestrianism          174.375272   67.803975
# Fencing                177.164177   71.387538
# Figure Skating         169.500000   65.500000
# Football               175.402195   70.446834
# Golf                   174.290076   71.194444
# Gymnastics             162.936020   56.916553
# Handball               183.384592   81.497151
# Hockey                 173.359676   69.169909
# Ice Hockey             175.150000   74.000000
# Jeu De Paume           178.500000         NaN
# Judo                   174.187353   78.759867
# Lacrosse               174.000000   76.714286
# Modern Pentathlon      177.944316   70.279540
# Motorboating           181.000000   77.000000
# Polo                   175.500000         NaN
# Racquets               176.000000         NaN
# Rhythmic Gymnastics    167.870253   48.760976
# Roque                         NaN         NaN
# Rowing                 184.172222   80.035863
# Rugby                  176.096774   77.533333
# Rugby Sevens           175.363636   78.939799
# Sailing                178.262199   75.975154
# Shooting               173.572174   74.027877
# Softball               169.395089   67.471655
# Swimming               178.562454   70.588492
# Synchronized Swimming  168.481481   55.863529
# Table Tennis           171.253773   64.956449
# Taekwondo              176.750836   68.007475
# Tennis                 178.898139   70.802291
# Trampolining           166.582781   59.322148
# Triathlon              173.645833   61.817490
# Tug-Of-War             182.480000   95.615385
# Volleyball             186.994822   78.900214
# Water Polo             184.834648   84.566446
# Weightlifting          167.824801   78.726663
# Wrestling              172.358586   75.495570

# %%
scatter_df=df[df['Season']=="Summer"].groupby("Sport")[["Height(cm)","Weight(kg)"]].mean().reset_index()
scatter_df
# Out:
#                     Sport  Height(cm)  Weight(kg)
# 0             Aeronautics         NaN         NaN
# 1                Alpinism         NaN         NaN
# 2                 Archery  173.203085   70.011135
# 3        Art Competitions  174.644068   75.290909
# 4               Athletics  176.256268   69.249287
# 5               Badminton  174.178803   68.171439
# 6                Baseball  182.599291   85.707792
# 7              Basketball  190.869879   85.777053
# 8           Basque Pelota         NaN         NaN
# 9        Beach Volleyball  186.144954   79.089219
# 10                 Boxing  172.825688   65.249890
# 11               Canoeing  178.539568   76.492615
# 12                Cricket         NaN         NaN
# 13                Croquet         NaN         NaN
# 14                Cycling  176.108826   70.067944
# 15                 Diving  166.634264   60.572741
# 16          Equestrianism  174.375272   67.803975
# 17                Fencing  177.164177   71.387538
# 18         Figure Skating  169.500000   65.500000
# 19               Football  175.402195   70.446834
# 20                   Golf  174.290076   71.194444
# 21             Gymnastics  162.936020   56.916553
# 22               Handball  183.384592   81.497151
# 23                 Hockey  173.359676   69.169909
# 24             Ice Hockey  175.150000   74.000000
# 25           Jeu De Paume  178.500000         NaN
# 26                   Judo  174.187353   78.759867
# 27               Lacrosse  174.000000   76.714286
# 28      Modern Pentathlon  177.944316   70.279540
# 29           Motorboating  181.000000   77.000000
# 30                   Polo  175.500000         NaN
# 31               Racquets  176.000000         NaN
# 32    Rhythmic Gymnastics  167.870253   48.760976
# 33                  Roque         NaN         NaN
# 34                 Rowing  184.172222   80.035863
# 35                  Rugby  176.096774   77.533333
# 36           Rugby Sevens  175.363636   78.939799
# 37                Sailing  178.262199   75.975154
# 38               Shooting  173.572174   74.027877
# 39               Softball  169.395089   67.471655
# 40               Swimming  178.562454   70.588492
# 41  Synchronized Swimming  168.481481   55.863529
# 42           Table Tennis  171.253773   64.956449
# 43              Taekwondo  176.750836   68.007475
# 44                 Tennis  178.898139   70.802291
# 45           Trampolining  166.582781   59.322148
# 46              Triathlon  173.645833   61.817490
# 47             Tug-Of-War  182.480000   95.615385
# 48             Volleyball  186.994822   78.900214
# 49             Water Polo  184.834648   84.566446
# 50          Weightlifting  167.824801   78.726663
# 51              Wrestling  172.358586   75.495570

# %% [markdown]
# ## Part 4: Plotting the data

# %% [markdown]
# __Question 1.__
# - Take the result of the previous question and display a scatter plot representing the average weight as a function of the average height. (That means we statistically assume that height "causes" weight. When plotting, that means put height on the horizontal or X-axis and weight on the Y-axis). Don't take into account NaN values. (tip: use the dropna() method for this).
#
# - Does theses values seem to be correlated? Is there some outlier sport? Don't forget to put a title and axes labels to your figure.
#
# __(bonus)__ Print a regression line on top of your graph. Change its color so we can see it well. (tip: search numpy library to get a function for the regression).
#
# __(bonus)__ Change the color and add the labels with the name of sport for the outliers points.

# %%
scatter_df.dropna(inplace=True)
scatter_df.reset_index(inplace=True)
scatter_df
# Out:
#     index                  Sport  Height(cm)  Weight(kg)
# 0       2                Archery  173.203085   70.011135
# 1       3       Art Competitions  174.644068   75.290909
# 2       4              Athletics  176.256268   69.249287
# 3       5              Badminton  174.178803   68.171439
# 4       6               Baseball  182.599291   85.707792
# 5       7             Basketball  190.869879   85.777053
# 6       9       Beach Volleyball  186.144954   79.089219
# 7      10                 Boxing  172.825688   65.249890
# 8      11               Canoeing  178.539568   76.492615
# 9      14                Cycling  176.108826   70.067944
# 10     15                 Diving  166.634264   60.572741
# 11     16          Equestrianism  174.375272   67.803975
# 12     17                Fencing  177.164177   71.387538
# 13     18         Figure Skating  169.500000   65.500000
# 14     19               Football  175.402195   70.446834
# 15     20                   Golf  174.290076   71.194444
# 16     21             Gymnastics  162.936020   56.916553
# 17     22               Handball  183.384592   81.497151
# 18     23                 Hockey  173.359676   69.169909
# 19     24             Ice Hockey  175.150000   74.000000
# 20     26                   Judo  174.187353   78.759867
# 21     27               Lacrosse  174.000000   76.714286
# 22     28      Modern Pentathlon  177.944316   70.279540
# 23     29           Motorboating  181.000000   77.000000
# 24     32    Rhythmic Gymnastics  167.870253   48.760976
# 25     34                 Rowing  184.172222   80.035863
# 26     35                  Rugby  176.096774   77.533333
# 27     36           Rugby Sevens  175.363636   78.939799
# 28     37                Sailing  178.262199   75.975154
# 29     38               Shooting  173.572174   74.027877
# 30     39               Softball  169.395089   67.471655
# 31     40               Swimming  178.562454   70.588492
# 32     41  Synchronized Swimming  168.481481   55.863529
# 33     42           Table Tennis  171.253773   64.956449
# 34     43              Taekwondo  176.750836   68.007475
# 35     44                 Tennis  178.898139   70.802291
# 36     45           Trampolining  166.582781   59.322148
# 37     46              Triathlon  173.645833   61.817490
# 38     47             Tug-Of-War  182.480000   95.615385
# 39     48             Volleyball  186.994822   78.900214
# 40     49             Water Polo  184.834648   84.566446
# 41     50          Weightlifting  167.824801   78.726663
# 42     51              Wrestling  172.358586   75.495570

# %%
import matplotlib.pyplot as plt
import random

x=scatter_df['Height(cm)']
y=scatter_df['Weight(kg)']
sportname=list(scatter_df["Sport"])


plt.figure(figsize=(10,10))

plt.plot(x,y , 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x,y, 1)

y_jittered=[i+random.uniform(-0.5,0.5) for i in y] 

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# Add labels
for i in range(len(x)): 
    plt.annotate((sportname[i]), (x[i], y_jittered[i] ),fontsize=7)

# %%
for i in

# %% [markdown]
# __Question 2. (bonus)__
# Add a color scale representing the number of data we have for each point.

# %%
scatter_df1=df[df['Season']=="Summer"].groupby("Sport").agg({"Height(cm)":"mean","Weight(kg)":"mean","Age":"count"}).reset_index()
scatter_df1.rename(columns={"Age":"Count"},inplace=True)
scatter_df1.dropna(inplace=True)
scatter_df1.reset_index(inplace=True)
scatter_df1
# Out:
#     index                  Sport  Height(cm)  Weight(kg)  Count
# 0       2                Archery  173.203085   70.011135   2254
# 1       3       Art Competitions  174.644068   75.290909   3071
# 2       4              Athletics  176.256268   69.249287  37507
# 3       5              Badminton  174.178803   68.171439   1457
# 4       6               Baseball  182.599291   85.707792    893
# 5       7             Basketball  190.869879   85.777053   4350
# 6       9       Beach Volleyball  186.144954   79.089219    564
# 7      10                 Boxing  172.825688   65.249890   5729
# 8      11               Canoeing  178.539568   76.492615   6136
# 9      14                Cycling  176.108826   70.067944  10181
# 10     15                 Diving  166.634264   60.572741   2721
# 11     16          Equestrianism  174.375272   67.803975   6151
# 12     17                Fencing  177.164177   71.387538  10020
# 13     18         Figure Skating  169.500000   65.500000     46
# 14     19               Football  175.402195   70.446834   6370
# 15     20                   Golf  174.290076   71.194444    235
# 16     21             Gymnastics  162.936020   56.916553  25528
# 17     22               Handball  183.384592   81.497151   3633
# 18     23                 Hockey  173.359676   69.169909   5213
# 19     24             Ice Hockey  175.150000   74.000000     54
# 20     26                   Judo  174.187353   78.759867   3763
# 21     27               Lacrosse  174.000000   76.714286     36
# 22     28      Modern Pentathlon  177.944316   70.279540   1624
# 23     29           Motorboating  181.000000   77.000000     15
# 24     32    Rhythmic Gymnastics  167.870253   48.760976    658
# 25     34                 Rowing  184.172222   80.035863  10069
# 26     35                  Rugby  176.096774   77.533333    114
# 27     36           Rugby Sevens  175.363636   78.939799    299
# 28     37                Sailing  178.262199   75.975154   6301
# 29     38               Shooting  173.572174   74.027877  10627
# 30     39               Softball  169.395089   67.471655    478
# 31     40               Swimming  178.562454   70.588492  22671
# 32     41  Synchronized Swimming  168.481481   55.863529    905
# 33     42           Table Tennis  171.253773   64.956449   1948
# 34     43              Taekwondo  176.750836   68.007475    606
# 35     44                 Tennis  178.898139   70.802291   2738
# 36     45           Trampolining  166.582781   59.322148    152
# 37     46              Triathlon  173.645833   61.817490    529
# 38     47             Tug-Of-War  182.480000   95.615385    126
# 39     48             Volleyball  186.994822   78.900214   3395
# 40     49             Water Polo  184.834648   84.566446   3646
# 41     50          Weightlifting  167.824801   78.726663   3731
# 42     51              Wrestling  172.358586   75.495570   6663

# %%
x=scatter_df1['Height(cm)']
y=scatter_df1['Weight(kg)']
sportname=list(scatter_df1["Sport"])
count_list=list(scatter_df1['Count'])


plt.figure(figsize=(10,10))

plt.scatter(x, y, c=count_list, cmap="jet")
#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x,y, 1)

y_jittered=[i+random.uniform(-0.5,0.5) for i in y] 

#add linear regression line to scatterplot 
plt.plot(x, m*x+b)

# Add labels
for i in range(len(x)): 
    plt.annotate((sportname[i]), (x[i], y_jittered[i] ),fontsize=7)

# %% [markdown]
# __Question 3. (bonus)__
# Choose 3 sports and represent the evolution of average weight over average height over the years.
#
# Represent them first on 3 different graphs and then on the same one with different colors.

# %%
athelitcs_df=df[df['Sport']=="Athletics"].groupby("Year")[["Height(cm)","Weight(kg)"]].mean().reset_index()
fencing_df=df[df['Sport']=="Fencing"].groupby("Year")[["Height(cm)","Weight(kg)"]].mean().reset_index()
shooting_df=df[df['Sport']=="Shooting"].groupby("Year")[["Height(cm)","Weight(kg)"]].mean().reset_index()

# %%
athelitcs_df.head()
# Out:
#    Year  Height(cm)  Weight(kg)
# 0  1896  174.875000   70.068966
# 1  1900  178.578947   74.526316
# 2  1904  178.227273   73.714286
# 3  1906  180.352941   74.739726
# 4  1908  178.305994   73.819444

# %%
fig,ax=plt.subplots(nrows=1,ncols=3,figsize=(10,2))
fig.tight_layout()
ax[0].plot(athelitcs_df['Year'],athelitcs_df['Height(cm)'],color="green",label="height")
ax[0].plot(athelitcs_df['Year'],athelitcs_df['Weight(kg)'],color="blue",label="weight")
ax[0].set_title("Athletics")
leg = ax[0].legend(loc="center right")

ax[1].plot(fencing_df['Year'],fencing_df['Height(cm)'],color="green",label="height")
ax[1].plot(fencing_df['Year'],fencing_df['Weight(kg)'],color="blue",label="weight")
ax[1].set_title("Fencing")
leg = ax[1].legend(loc="center right")


ax[2].plot(shooting_df['Year'],shooting_df['Height(cm)'],color="green",label="height")
ax[2].plot(shooting_df['Year'],shooting_df['Weight(kg)'],color="blue",label="weight")
ax[2].set_title("Shooting")
leg = ax[2].legend(loc="center right")

# %%
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(15,7))
ax.plot(athelitcs_df['Year'],athelitcs_df['Height(cm)'],color="green",linestyle = '--',label='Athelitics height')
ax.plot(fencing_df['Year'],fencing_df['Height(cm)'],color="green",linestyle = '-.',label='fencing height')
ax.plot(shooting_df['Year'],shooting_df['Height(cm)'],color="green",linestyle = '-',label='shooting height')
ax.plot(athelitcs_df['Year'],athelitcs_df['Weight(kg)'],color="blue",linestyle = '--',label='Athelitics weight')
ax.plot(fencing_df['Year'],fencing_df['Weight(kg)'],color="blue",linestyle = '-.',label='fencing weight')
ax.plot(shooting_df['Year'],shooting_df['Weight(kg)'],color="blue",linestyle = '-',label='shooting weight')
leg = ax.legend(loc="center right")
